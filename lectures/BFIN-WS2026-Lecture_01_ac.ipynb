# %% [markdown]
# <center>
# <img src="../images/fscampus_small2.png" width="1200"/>
# </center>
#
# <center>
#
# # Investments
#
# ***Finance 2 - BFIN***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer_cayirli@uncbusiness.net
# </center>
#
#
# ---

# %% [markdown]
# ## Lecture 01
# ---

# %% [markdown]
# ### Outline
# * Intro
#   * Content & Objectives
#   * Course Materials
# * Rules of the Game
#   * Expectations & Norms
#   * Attendance & Participation
#   * Grading
# * Lecture
#   * The Investment Environment; Asset Classes and Financial Instruments
#
# ---

# %% [markdown]
# ### Intro
# * Course Content
#   * The Investment Environment
#     * Asset Classes and Financial Instruments
#   * Fixed-Income Securities
#   * Portfolio Theory and Practice
#   * Asset Pricing Models
#     * Index Models and The Capital Asset Pricing Model
#     * Arbitrage Pricing Theory
#     * Multifactor Models of Risk and Return
#   * The Efficient Market Hypothesis
#     * Behavioral Finance
#     * Empirical Evidence on Security Returns
#   * Derivatives
#     * Futures, Forwards, and Swaps
#     * Option Markets and Option Valuation
#
# ---

# %% [markdown]
# ### Intro
# * Objectives
#   * The analytical tools and theoretical concepts necessary for
#     * Making good investment decisions,
#     * Understanding the paradigms by which financial securities are valued.
#   * The students should
#     * acquire basic professional and methodological skills in the field of financial economics.
#     * be able to name and explain the characteristics and modes of operation of the most important financial instruments and the respective financial markets.
#     * possess the knowledge to present the most important models for the analysis of financial instruments, their assumptions as well as their limitations and apply the models to practical examples.
#     * be capable of presenting, interpreting and applying simple risk management strategies for securities portfolios.
#   * In this context,
#     * The lectures will explore issues closely related to asset pricing, asset allocation, and risk management.
#
# ---

# %% [markdown]
# ### Intro
# * Course Materials
#   * Books
#     * BKM, Bodie, Z., A. Kane and A. Marcus, Investments, 2021, 12th edition, International Student Edition, McGraw-Hill.
#   * Lecture slides
#     * Before each class (with exercises, without solutions)
#     * Updated after class (with solutions).
#
# ---

# %% [markdown]
# ### Rules
# * Expectations & Norms
#   * Be prepared for the class
#     * Assigned readings
#     * Previous class(es)
#   * Avoid scholastic offenses and adhere to the student conduct policies
# * Attendance
#   * Lectures will not be based solely on the book.
#   * Attendance and active class participation are important for achieving the learning goals.
#   * Students must comply with the University's attendance policy to earn credits for this course.
#   * Remember!: "Late arrivals to class are disruptive."
# * Participation
#   * We will have interactive classes and you are expected to contribute.
#   * You cannot contribute if you don't attend and participate.
#   * Cold calls should be expected.
#
# ---

# %% [markdown]
# ### Rules
# * Grading
#   * Lecturer's approach
#     * Grading is just a tool for measuring your relative performance.
#     * Do not act grade oriented.
#     * Our main goal is to learn collectively.
#   * Assessment based on portfolio approach
#     * Class contribution
#     * Two group assignments
#     * Final exam (75 minutes)
#
# ---

# %% [markdown]
# # <center>Questions?</center>
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Real Assets vs. Financial Assets
#   * Real Assets
#     * Have productive capacity
#   * Financial Assets
#     * Claims on real assets
#     * Do not contribute directly to productive capacity
#
# <center>
# <img src="../images/financial_assets.png" width="600"/>
# </center>
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Financial Markets and the Economy
#   * The Informational Role
#     * Stock prices reflect "collective” assessment of a firm's current performance and future prospects.
#   * Consumption Timing
#     * Use securities to store wealth and transfer consumption to the future
#       * Store of wealth in financial assets
#       * Buying/selling in different life periods
#   * Allocation of Risk
#     * Allows investors to select securities consistent with their risk preferences
#       * From high to low (shares/bonds) to different categories of investors
#   * Corporate Governance
#     * Monitoring by large investors and security analysts
#     * Takeover threat
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Financial Markets and the Economy
#   * Capital markets recognize and drive funds to the best ideas and enterprises.
#   * Markets facilitate the transfer of funds from those who seek a return on their assets to those who need capital to expand.
#   * Capital, raised through equity and debt, can be used to
#     * grow businesses,
#     * finance investments in new property, equipment, technology,
#     * fund infrastructure projects.
#   * Individuals and businesses can invest in securities to generate wealth.
#
# ---

# %% [markdown]
# ### The Investment Environment
# * The Investment Process
#   * Asset allocation
#     * Choice among broad asset classes (stocks; bonds; commodities; real estate; etc.)
#   * Security selection
#     * Choice of securities within each asset class
#   * Portfolio: Collection of investment assets
#     * "Top-down" approach
#       * Asset allocation followed by security analysis
#     * "Bottom-up” approach
#       * Starts with analysis and valuation of individual companies
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Competitive Markets
#   * Risk-Return Trade-Off
#     * Higher expected returns compensate for risk that cannot be diversified away.
#     * Higher risk does not guarantee higher returns.
#   * Efficient Markets
#     * Prices quickly adjust to all relevant information
#     * There should be neither underpriced nor overpriced securities
#   * Passive Management
#     * Holding a highly diversified portfolio
#     * No attempt to find undervalued securities
#     * No attempt to time the market
#   * Active Management
#     * Finding mispriced securities
#     * Timing the market
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Fixed Income
#
# <center>
# <img src="../images/slide_1/pic_1.png" width="600"/>
# </center>
#
# * The Money Market
#   * Short-term
#   * Liquid
#   * Generally low risk
# * The Capital Market
#   * Long-term
#   * Liquidity (depends)
#   * Higher risk/return
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
# * Fixed Income
#   * The Money Market
#     * Treasury Bills
#     * Certificates of Deposit
#     * Commercial Paper
#     * Eurodollars
#     * Repos and Reverses
#     * Federal Funds
#     * SOFR-linked Instruments
#     * Money Market Funds
#   * The Capital Market
#     * Treasury Notes and Bonds
#     * Inflation-Protected Treasury Bonds
#     * Federal Agency Debt
#     * International Bonds
#     * Municipal Bonds
#     * Corporate Bonds
#     * Asset-Backed Securities
#     * Mortgage-Backed Securities
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Equity
# <center>
# <img src="../images/slide_1/pic_2.png" width="600">
# </center>
#
# * Common stock
#   * Ownership
#   * Residual claim
#   * Limited liability
# * Preferred stock:
#   * Equity, often with no maturity date
#   * Usually fixed dividends, paid at the firm's discretion
#   * Priority over common
#   * Tax treatment
# * American Depository Receipts (ADR)
#   * Certificates traded in U.S. markets that represent ownership in shares of a foreign company
#   * Makes it easier for foreign firms to satisfy U.S. security registration requirements
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Derivatives
#
# <center>
# <img src="../images/slide_1/pic_3.png" width="600">
# </center>
#
# * A derivative is a security that gets its value from the value of another asset, such as commodity prices, bond and stock prices, or market index values
#   * Their values derive from the values of other assets.
#   * Also called contingent claims because their payoffs are contingent on the value of other assets.
# * Options: Right to sell/buy
# * Futures/Forwards: Obligation to deliver/receive in exchange for cash
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Derivatives
# * Options
#   * A call option gives its holder the right to purchase an asset for a specified price, called the exercise or strike price, on or before a specified expiration date.
#   * A put option gives its holder the right to sell an asset for a specified exercise price on or before a specified expiration date.
#   * Options may or may not be exercised.
# * Futures/Forwards
#   * A futures contract calls for delivery of an asset (or, in some cases, its cash value) at a specified delivery or maturity date for an agreed-upon price, called the futures price, to be paid at contract maturity.
#     * The long position is held by the party who commits to purchasing the asset on the delivery date.
#     * The party who takes the short position commits to delivering the asset at contract maturity.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_4.png">
# </center>
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
#
# Note: Data reflect stock of all non-financial corporations’ financing as of year-end 2025. Data for China as of year-end 2023. Euro Area includes 21 EU member states using the Euro. Debt securities include financial liabilities like corporate bonds, municipal securities, commercial paper, etc. Other
# financing (excluding China) includes insurance reserves, trade credits and trade advances and other. China includes bankers' acceptances, FDI, other
# foreign A/D, misc. and errors.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_5.png">
# </center>
#
# Source: [SIFMA 2026 Capital Markets Outlook](https://www.sifma.org/wp-content/uploads/2026/03/SIFMA-Capital-Markets-Outlook-2026.pdf)
#
# Note: Market capitalization of listed domestic companies. DM = developed markets, EM = emerging markets, DM/EM exclude countries already listed in
# the chart. HK = Hong Kong.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_6.png">
# </center>
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
#
# Note: Notional principal value. Includes interest rates, foreign exchange, equity linked, commodities, credit, and credit default swaps.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_7.png">
# </center>
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
#
# Note: Long-term includes securities with maturity >13 months; global equity issuance includes non-convertible IPOs and follow-on
# equity deals, excludes preferred shares, rights issues, closed-end funds, business development companies, and special purpose acquisition companies
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_8.png">
# </center>
#
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
# Note: International offerings are securities issued outside the issuer’s domestic market.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_9.png">
# </center>
#
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
#
# Note: End of year closing index levels.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# **Table 12: Major Global Stock Market Indexes (Y/Y Percentage Change)**
#
# <center>
# <img src="../images/slide_1/pic_10.png">
# </center>
#
#
# Source: [2026 SIFMA Capital Markets Fact Book](https://www.sifma.org/wp-content/uploads/2025/07/SIFMA-Capital-Markets-Fact-Book-2026-Edition.pdf)
#
# Note: End of year closing price, local currency.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Delta has issued both common and preferred shares. Which statement best describes the rights typically associated with its common shares?
#
#   a. Holders receive a fixed dividend that takes priority over dividends paid to preferred shareholders.
#
#   b. Holders typically have voting rights and a residual claim on assets after creditors and preferred shareholders have been paid.
#
#   c. Holders receive their original investment back before preferred shareholders if Delta is liquidated.
#
# Choose one answer and briefly explain why the other two are incorrect.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * An investor studies Gamma’s earnings, competitive position, and estimated intrinsic value. The investor decides to buy its shares because they appear undervalued, despite a weak outlook for the broader industry. Which investment approach best describes this decision?
#
#   a. A bottom-up investment process focused on the fundamentals of individual companies.
#
#   b. A top-down investment process that selects attractive economic sectors before choosing individual companies.
#
#   c. A passive investment strategy that replicates the holdings of a market index.
#
# Choose one answer and briefly explain which feature of the investor’s decision supports your choice.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * An investor buys a call option on Theta shares with a strike price of \$60. At expiration, which statement correctly describes the investor’s position?
#
#   a. The investor must buy Theta shares for \$60 per share, regardless of their market price.
#
#   b. The investor has the right, but no obligation, to sell Theta shares for \$60 per share.
#
#   c. The investor has the right, but no obligation, to buy Theta shares for \$60 per share.
#
# Choose one answer and briefly explain how a contractual right differs from a contractual obligation.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Lambda has surplus cash and provides short-term financing to Sigma through a reverse repurchase agreement. Which sequence of transactions describes Lambda’s position?
#
#   a. Lambda buys securities from Sigma today and agrees to resell them to Sigma on a specified future date at an agreed price.
#
#   b. Lambda sells securities to Sigma today and agrees to repurchase them from Sigma on a specified future date at an agreed price.
#
#   c. Lambda buys securities from Sigma today without any agreement for a future resale.
#
# Choose one answer and explain why Sigma would describe the same transaction as a repurchase agreement.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# **Credit Spreads**
#
# The economy enters a severe recession. How would you expect the yield spread between Omega’s commercial paper and Treasury bills of the same maturity to change? Explain the roles of default risk and investors’ preference for safety.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# **Comparing Securities**
#
# For each pair below, identify which security should have the higher price and explain why. Assume all characteristics are identical except the difference explicitly stated.
#
# a. Two 10-year Treasury bonds, each with a face value of \$1,000 and annual coupon payments: one has a 6% coupon rate, and the other has a 4% coupon rate.
#
# b. Two call options on Kappa shares, both expiring in three months: one has a \$50 strike price, and the other has a \$55 strike price.
#
# c. Two put options on Kappa shares, both expiring in three months: one has a \$50 strike price, and the other has a \$55 strike price.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Call and put options are traded on Epsilon shares. Both have a strike price of \$80 and expire in one month. The call premium is \$4 per share, and the put premium is \$3 per share.
#
#   For each stock price at expiration below, calculate the payoff and net profit per share for an investor who buys the call and an investor who buys the put. Ignore transaction and financing costs.
#
#   a. \$70
#
#   b. \$77
#
#   c. \$80
#
#   d. \$83
#
#   e. \$90
#
# * What is the difference between a put option and a short position in a futures contract?
#
# * What is the difference between a call option and a long position in a futures contract?
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# Zeta is a biotechnology startup. It owns laboratory equipment worth \$100,000 and holds \$60,000 in cash contributed by its founders.
#
# For each transaction below, identify the real and financial assets involved. Explain whether financial claims are created, transferred, or extinguished. Ignore interest, taxes, and transaction costs.
#
# a. Zeta issues five-year corporate bonds with a total face value of \$250,000 and receives \$250,000 in cash.
#
# b. Zeta uses the bond proceeds and \$40,000 of its existing cash to develop a new drug, obtaining a patent for the formula.
#
# c. Zeta transfers the patent to Eta, a pharmaceutical company. In exchange, Eta issues 6,000 new common shares to Zeta.
#
# d. Zeta sells all 6,000 Eta shares to other investors for \$50 per share. It uses part of the proceeds to redeem all its outstanding bonds at face value.
#
# ---

# %% [markdown]
# ### What is next?
# * Fixed-Income Securities
#   * Readings: Ch. 14 & 15
#
# ---
